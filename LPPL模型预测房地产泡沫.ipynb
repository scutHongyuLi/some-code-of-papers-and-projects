# %% [markdown]
# # 0.1--SADF检验（上确界ADF检验）

# %% [markdown]
# ### 回归方程：
# $$
# \Delta \mathrm{X}_{\mathrm{t}}=\mu+\rho \mathrm{X}_{\mathrm{t}}+\alpha_{\mathrm{i}} \sum_{\mathrm{i}=1}^{\mathrm{d}} \Delta \mathrm{X}_{\mathrm{t}-\mathrm{i}}+\varepsilon_{\mathrm{t}}
# $$

# %% [markdown]
# ### SADF检验的原假设表示为H0: p =0, 表示Xt序列平稳,而备择假设H1:p>0,表示序列不平稳且具有爆炸性过程,SADF检验步骤如下:
# ### (1) : 对于给定的样本T,选定最小窗宽r0(其中0<r0<1, 一般r0取为0.1,0.2或0.4), 即最小样本量为r0T, 设回归的起点为r1, 移动回归的终止点为r2,则固定回归的起始点r1为0, 第一次回归检验模型的终止点r2为r0T, 根据该序列进行ADF检验,得到ADF检验统计量
# ### (2) : 回归起始点固定r1仍为0, 将回归终止点r2逐次前向递归,即终止点变为roT+1, roT+2, ....(其中, roT <= r2 <= T), 对每个子样本序列进行ADF检验,得到一共含有(T - roT + 1)个ADF统计量的序列值.
# ### (3) : 取这组ADF统计量序列最大值,即上确界就是SADF统计量的值,公式表示如下:
# $$
# \operatorname{SADF}\left(r_{0}\right)=\sup _{r_{2} \in\left[r_{0} \mathrm{T}, \mathrm{T}\right]} A D F_{r_{1}}^{r_{2}}
# $$
# ### (4) : 通过对比SADF检验统计量的对应的SADF标准检验统计量的临界值得大小关系,判断泡沫是否存在并得出结论

# %% [markdown]
# # 0.2--GSADF检验(扩展的上确界单位根检验, 增广的确界单位根检验)

# %% [markdown]
# ### SADF检验的提出是为了检验单个泡沫存在的情况,它仅仅是向前移动递归终止点,而起始点保持不变,这只是SADF检验在检验多个泡沫时的检验势较低. 假如在一个时间段内有两次泡沫出现,且第二次泡沫出现的时间比第一次泡沫出现的时间短, 那SADF检验就不能有效的分析出第二次泡沫. 为了弥补这一不足,PSY提出了GSADF检验法,GSADF方法是在SADF检验的基础上进行拓展, 将SADF检验方法估计窗口中固定的起始点r0变为前向递归的起始点,也就是说,在GSADF检验中,不仅考虑了向前递归的回归终止点,而且还考虑了前向递归的回归起始点. 显而易见,SADF检验方法包含于GSADF中,GSADF对SADF方法进行了深度的拓展.同样,在GSADF方法中,其用于检验的回归方程和假设与SADF方法相同. 具体步骤如下:
# ### (1) : 对于给定的样本T,选定最小窗宽r0(其中0<r0<1, 一般取r0为0.1, 0.2 或者0.4), 即最小样本量为 r0T, 设回归的起始点为r1, 移动回归的终止点为r2. 对该序列进行ADF检验,得到对应的ADF统计量.
# ### (2) : 回归起始点固定r1不变,将回归终止点r2逐次向前递归,对每个子序列进行ADF检验,得到一组ADF统计量的序列,保留其最大值Max_ADF_r10
# ### (3) : 改变回归起始点r1, 即将回归起始点向前递归,其中r1∈[1, T-r0T+1], 重复上述步骤(1) 与步骤(2),得到一系列ADF统计量最大值的序列. Max_ADF_r11, Max_ADF_r12, ....
# ### (4) : 这组ADF统计量最值序列中的最大值,极为GSADF检验统计量,具体公式表示如下:
# $$
# \operatorname{GSADF}\left(r_{0}\right)=\sup _{r_{1} \in\left[1, T-r_{0} T+1\right]} A D F_{r_{1}}^{r_{2}}
# $$
# ### (5) : 通过对比GSADF检验统计量和对应的临界值之间的大小关系,判定是否存在房地产泡沫

# %% [markdown]
# ### 关于SADF检验统计量和GSADF检验统计量对应的临界值,很多学者选择利用蒙特卡洛法进行模拟计算,为了简化实证模型,考虑到已有学者给出的临界值计算公式,本文直接采用Phillips 和 Yu(2011c)使用的保守公式计算临界值,即:
# $$
# \mathrm{cv}=-0.08+\frac{\ln (T)}{5}
# $$
# ### 通过该公式所计算得出的临界值序列接近SADF和GSADF在5%显著性水平下的临界值, 且该临界值序列的值随样本时间长度的增加而缓慢增加,由于是右尾单位根检验,当GSADF统计量大于该lin

# %% [markdown]
# # 1、对数周期幂律模型

# %% [markdown]
# $$
# \ln p_{t} \approx A+B\left(t_{c}-t\right)^{\beta}+C\left(t_{c}-t\right)^{\beta} \cos \left[\omega \ln \left(t_{c}-t\right)+\phi\right]
# $$

# %% [markdown]
# ## 其中
# ### tc为临界时间点，
# ### p(t)为t时刻股票价格；
# ### A = lnp(tc)>0, 为p(t)在临界时刻的对数值；
# ### B<0为C无限接近于零时单位时间内增长量；
# ### C为指数增长的波动振幅因子。
# ### β为幂指数，
# ### w为波动频率，
# ### $\phi$为相位

# %% [markdown]
# # 2、模型解释

# %% [markdown]
# ##  趋同和羊群效应导致泡沫的产生，幂指数β值得大小是由市场上理性投资者和非理性投资者的各自占比决定, 资产的价格因投资者之间正反馈作用的存在，呈现出幂指数的形式增长，而w值的大小是由投资者观点一致性程度决定的

# %% [markdown]
# ## 根据该模型，资产价格随时间增长有着近似指数增长的特点，同时也伴随着不断地振荡。但是随着时间越来越节点临界时间点，振荡地幅度逐渐减弱，增长速度逐渐增大，进入超指数的增长状态，最终市场在临界点时间点附近崩盘。

# %% [markdown]
# # 3、待估参数：
#  $tc$，$A$，$B$，$C$，$β$，$w$，$\phi $

# %% [markdown]
# ## 拟合对数周期幂律方程：Parameter = $argmin (lnP - lnP_{pred}) ^ 2$
# ## 即最小化以下损失函数（最小二乘法）
# $$
# S E=\sum_{t=t_{1}}^{t_{n}}\left(y_{t}-\hat{y}_{t}\right)^{2}=\sum_{t=t_{1}}^{t_{m}}\left\{y_{t}-A-B\left(t_{c}-t\right)^{\beta}\left[1+C \cos \left(\omega \log \left(t_{c}-t\right)+\phi\right]\right\}^{2}\right.      -----    (10)
# $$

# %% [markdown]
# ## 当待估参数过多时（有七个参数），目标函数容易陷入局部最小值，这可以通过减少待估参数的个数方法，提高待估参数拟合的精度
# ## 因此对LPPL模型公式进行简化

# %% [markdown]
# $$
# \ln p_{t} \approx A+B\left(t_{c}-t\right)^{\beta}+C\left(t_{c}-t\right)^{\beta} \cos \left[\omega \ln \left(t_{c}-t\right)+\phi\right]
# $$
# $$
# y_{t}=A+B f_{t}+C g_{t}          ----- （11）
# $$

# %% [markdown]
# ## 其中
# $$
# \begin{array}{l}{y_{t}=\ln p_{t}} \\ {f_{t}=\left(t_{c}-t\right)^{\beta}} \\ {g_{t}=\left(t_{c}-t\right)^{\beta} \cos \left(\omega \ln \left(t_{c}-t\right)+\phi\right)}\end{array}      ------  (12)
# $$

# %% [markdown]
# $$
# S E=\sum_Σ(y_t - A - Bf_{t} - Cg_{t})^2
# $$

# %% [markdown]
# $$
# \left(\begin{array}{c}{\sum_{i=1}^{N} y_{i}} \\ {\sum_{i=1}^{N} y_{i} f_{i}} \\ {\sum_{i=1}^{N} y_{i} g_{i}}\end{array}\right)=\left(\begin{array}{ccc}{N} & {\sum_{i=1}^{N} f_{i}} & {\sum_{i=1}^{N} g_{i}} \\ {\sum_{i=1}^{N} f_{i}} & {\sum_{i=1}^{N} f_{t}^{2}} & {\sum_{i=1}^{N} f_{i} g_{i}} \\ {\sum_{i=1}^{N} g_{i}} & {\sum_{i=1}^{N} f_{i} g_{i}} & {\sum_{i=1}^{N} g_{i}^{2}}\end{array}\right)\left(\begin{array}{c}{A} \\ {B} \\ {C}\end{array}\right)
# $$

# %% [markdown]
# # 4、求解参数
#
# ## 通过拟合出 $tc$，$A$，$B$，$C$，$β$，$w$，$\phi $ 这几个参数就可以得到泡沫破裂的时期

# %% [markdown]
# # 5、参数分析：
# ## 最后拟合出来的$t_c$表示泡沫破裂的时间（是距离我们定的起点的泡沫破裂的时间，比方说：我们使用2019-03-01至2019-05-01这段时间的数据来拟合参数，拟合得到的$t_c$=70，则表示泡沫发生在距离2019-03-01这个日期70天左右，即2019-05-10号左右）

# %% [markdown]
# ### 导入相关库

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import scale
# %matplotlib inline
from pylab import mpl
import matplotlib.pyplot as plt
mpl.rcParams['font.sans-serif'] = ['FangSong'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题
import warnings

warnings.filterwarnings('ignore')

from jqdatasdk import *
auth('18023476141', 'qq827064298')  # 登陆聚宽账号
auth('18023475745', '475745')
path = 'C:/Users/82706/Desktop/LPPL/'
# Out:
# auth success  ( 如需说明文档请查看：https://url.cn/5oB7EOO，更多问题请联系JQData管理员，微信号：JQData02 )

# %%
WanKeA = get_price('000002.XSHG', start_date='2005-01-01', end_date='2020-01-01', frequency='daily',fq='pre')

# %% [markdown]
# # 进化算法

# %%
def fit(P0):  
    fitne = np.zeros(P0.shape[0])
    for i in range(P0.shape[0]):     
        P = P0[i]
        tc = P[0]
        beta = P[1]
        w = P[2]
        phi = P[3] 

        f = np.array([(tc - t)**beta for t in range(N)])
        g = np.array([(tc - t)**beta * np.cos(w*np.log(tc-t)+ phi) for t in range(N)])
        M = np.linalg.pinv(np.matrix([[N,np.sum(f), np.sum(g)],
                      [np.sum(f), np.sum(f**2), np.sum(f*g)],
                      [np.sum(g), np.sum(f*g), np.sum(g**2)]]))
        m = np.matrix([[np.sum(y)], [np.sum(y*f)], [np.sum(y*g)]])
        A,B,C = np.dot(M,m).tolist()
        fitne[i] = np.sum((y - A - B*f - C*g)**2)
    return fitne

def get_fitness(pred):
    return pred.flatten()

### 繁殖产生新的种群
def make_kid(pop, n_kid, DNA_SIZE,POP_SIZE,gen):

    kids = np.zeros((n_kid, DNA_SIZE))  # 后代种群(空)

    ### 对每个后代进行赋值（根据父母）
    for i in range(n_kid):
        parent1, parent2 = np.random.choice(np.arange(POP_SIZE), size=2, replace=False)    # 选择参与交叉得个体（即选择双亲）
        cp = np.random.randint(0, 2, DNA_SIZE, dtype=np.bool)                              # 选择交叉得位置
        kids[i,cp] =  pop[parent1, cp]                                                     # 交叉后得个体
        kids[i,~cp] = pop[parent2, ~cp]                                                    # 交叉后得个体
        # 变异
        kids[i,0]  += 10 * np.random.randn(1) / np.sqrt(gen+1)
        kids[i,1:] +=  np.random.randn(1) / np.sqrt(gen+1)
        # 防止超出上下界 
        kids[i,0] = np.clip(kids[i,0], N,N+180)                      # tc
        kids[i,1] = np.clip(kids[i,1], 0,1)                          # beta
        kids[i,2] = np.clip(kids[i,2], 6,13)                         # w
        kids[i,3] = np.clip(kids[i,3], 0, 2*np.pi)                   # phi
        
    kids_fitness = get_fitness(fit(kids))
        
    return kids, kids_fitness

def kill_bad(pop, kids,  POP_SIZE,parent_fitness, kids_fitness):
    
    # 把父母和孩子放在一起
    pop = np.vstack([pop, kids])                                # 按行合并 
    fitness = np.hstack([parent_fitness, kids_fitness])

    best_index = np.argmin(fitness)                             #  最优个体索引
    best_pop = pop[best_index,:]                                # 最优个体
    good_index = np.argsort(fitness)[:POP_SIZE]                 # 选出适应度最小得前POP_SIZE个个体,np.argsort()从小到大排序
    pop = pop[good_index]                                       # 更新种群
    parent_fitness = fitness[good_index]                        # 更新父代适应度
    return pop,best_pop,parent_fitness 


def GA(DNA_SIZE,POP_SIZE, N_KID,N_GENERATIONS):
    pop = np.random.normal(np.array([N,.5,10,3.14]),np.array([10,1, 1,1]), size=(POP_SIZE, DNA_SIZE))  #初始种群
    pop[:,0] = np.clip(pop[:,0], N,N+180)                        # tc
    pop[:,1] = np.clip(pop[:,1], 0,1)                            # beta
    pop[:,2] = np.clip(pop[:,2], 6,13)                           # w
    pop[:,3] = np.clip(pop[:,3], 0, 2*np.pi)                     # phi
    Best_pop = pop[0]                                            # 初始化最好个体|
    parent_fitness = get_fitness(fit(pop))
    for gen in range(N_GENERATIONS):
        kids, kids_fitness = make_kid(pop, N_KID,DNA_SIZE,POP_SIZE,gen)
        pop,Best_pop,parent_fitness = kill_bad(pop, kids,  POP_SIZE,parent_fitness,kids_fitness)

    return Best_pop

# %% [markdown]
# # 检验函数

# %%
def test(P0):
    tc = P0[0]
    beta = P0[1]
    w = P0[2]
    phi = P0[3] 
    f = np.array([(tc - t)**beta for t in range(N)])
    g = np.array([(tc - t)**beta * np.cos(w*np.log(tc-t)+ phi) for t in range(N)])
    M = np.linalg.pinv(np.matrix([[N,np.sum(f), np.sum(g)],
                  [np.sum(f), np.sum(f**2), np.sum(f*g)],
                  [np.sum(g), np.sum(f*g), np.sum(g**2)]]))
    m = np.matrix([[np.sum(y)], [np.sum(y*f)], [np.sum(y*g)]])
    A,B,C = np.dot(M,m).tolist()
    
    A,B,C = A[0],B[0],C[0]
#     print('tc:%f，A:%f，B:%f，C:%f，β:%f，w:%f，ϕ:%f'%(tc,A,B,C,beta,w,phi))
    p_predict = [np.exp(A+B*(tc-t)**beta + C*(tc-t)**beta*np.cos(w*np.log(tc-t)+phi))  for t in range(N)]
    index = df[start:end].index
    # %matplotlib notebook
    plt.figure(figsize=(12,7))
    plt.plot(index,p_predict, label='拟合曲线',c='b')
    plt.plot(index, pt, label='真实曲线',c='r')
    plt.xticks(index[::10],rotation=90)
#     plt.grid(axis='x')
    plt.savefig(path+name+start+'-'+end+'检验图.png',dpi=300)
    plt.title(name)
    plt.legend()

# %%
df = WanKeA.dropna()
name = '万科A'

# %%
# %matplotlib notebook
plt.figure(figsize=(12,7))
plt.plot(df.index, df.close.values)
plt.xticks(df.index[::100], rotation=90)
plt.text(df.loc['2007-10-16'].name,df.loc['2007-10-16'].close,s='泡沫破裂点：2007-10-16',c='k')
plt.scatter(df.loc['2007-10-16'].name,df.loc['2007-10-16'].close,c='r')
plt.text(df.loc['2015-06-12'].name,df.loc['2015-06-12'].close,s='泡沫破裂点：2015-06-12',c='k')
plt.scatter(df.loc['2015-06-12'].name,df.loc['2015-06-12'].close,c='r')
# plt.grid(axis='x',linestyle='-', linewidth=0.5)
plt.title(name+'收盘价')
plt.savefig(path+name+'走势图.png',dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="864">

# %%
True_date = '2015-06-12'
start = '2014-06-30'
end = '2015-04-24'
pt = df[start:end]['close'].astype('float').values
N = len(pt)
y = np.log(pt)

# %%
Pars = []
for i in range(10):
    par = GA(DNA_SIZE=4,POP_SIZE=100, N_KID=50,N_GENERATIONS=50)
    Pars.append(par)

# %% [markdown]
# ## 测试拟合效果

# %%
test(np.mean(np.array(Pars),axis=0))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3600x2100 at 0x173BD36D898>

# %% [markdown]
# ## 蓝线是拟合出来的曲线，红线是真正的价格曲线

# %%
Tc = np.mean([i[0] for i in Pars])

# %%
# %matplotlib notebook
plt.figure(figsize=(15,8))
plt.plot(df['close'].index, df['close'].astype('float').values)
plt.vlines(df[start:]['close'].index[0],np.min(df['close'].values),np.max(df['close'].values),linestyles='dashed',color='g' ,label='区间开始:'+str(start))
plt.plot(df[start:end]['close'].index, df[start:end]['close'].astype('float').values, color='r')
plt.vlines(df[start:]['close'].index[N], np.min(df['close'].values),np.max(df['close'].values),linestyles='dashed',label='区间结束:' +str(end))
plt.vlines(df[start:]['close'].index[int(Tc)], np.min(df['close'].values),np.max(df['close'].values),label='预测泡沫破裂:'+str(df[start:]['close'].index[int(Tc)])[:10])
plt.vlines(True_date, np.min(df['close'].values),np.max(df['close'].values),color='r',label='真正泡沫破裂:' +True_date)
plt.xticks(df['close'].index[::50],rotation=90)
plt.legend()
plt.savefig(path+name+start+'-'+end+'.png',dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="1080">

# %% [markdown]
# ## 绿色的虚线是我们认为定义的起点
# ## 黑色的虚线是当前时刻
# ## 黑色的实线是预测未来泡沫破裂的时刻
